# %%
#pip install alpha_vantage pandas

# %% [markdown]
# ## IMPORTING LIBRARIES

# %%
#libraries
import os
from alpha_vantage.foreignexchange import ForeignExchange
from datetime import datetime

import matplotlib.pyplot as plt
from dotenv import load_dotenv
dotenv_path = os.path.join(os.getcwd(), '.env')
load_dotenv(dotenv_path)
alpha = os.environ['ALPHA']


from pprint import pprint
import pandas as pd
import numpy as np
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\Users\aerku\AppData\Local\anaconda3\envs\pyvizenv\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %%
#API Key
fx = ForeignExchange(key='alpha')

# %% [markdown]
# ## GETTING DAILY CURRENCY EXCHANGE DATA

# %% [markdown]
# # EURO - EUR

# %%
#EUR-USD DATA
data, meta_data = fx.get_currency_exchange_daily(from_symbol='EUR',to_symbol='USD', outputsize='full')

EUR_df = pd.DataFrame()

for date in data:
    temp = pd.DataFrame(
    {
        "Date" : date,
        "EUR" : [data[date]['4. close']]
    }
    )
    
    EUR_df = pd.concat([EUR_df, temp], ignore_index=True)
    
EUR_df['Date'] = pd.to_datetime(EUR_df['Date'])
EUR_df['EUR'] = EUR_df['EUR'].astype('float')
EUR_df.set_index('Date', inplace = True)
EUR_df.sort_index(ascending=False)
EUR_df.head()
# Out:
#                EUR
# Date
# 2021-02-03  1.2037
# 2021-02-02  1.2042
# 2021-02-01  1.2059
# 2021-01-29  1.2136
# 2021-01-28  1.2120

# %%
EUR_df.plot()
plt.tight_layout()
plt.title('Daily close value for EUR - USD')
plt.grid()
plt.show()

# %% [markdown]
# ## BRAZILIAN REAL - BRL

# %%
#BRL-USD DATA
data, meta_data = fx.get_currency_exchange_daily(from_symbol='BRL',to_symbol='USD', outputsize='full')

BRL_df = pd.DataFrame()

for date in data:
    temp = pd.DataFrame(
    {
        "Date" : date,
        "BRL" : [data[date]['4. close']]
    }
    )
    
    BRL_df = pd.concat([BRL_df, temp], ignore_index=True)
    
BRL_df['Date'] = pd.to_datetime(BRL_df['Date'])
BRL_df['BRL'] = BRL_df['BRL'].astype('float')
BRL_df.set_index('Date', inplace = True)
BRL_df.sort_index(ascending=False)    

BRL_df.head()
# Out:
#                BRL
# Date
# 2021-02-03  0.1858
# 2021-02-02  0.1858
# 2021-02-01  0.1836
# 2021-01-29  0.1826
# 2021-01-28  0.1833

# %%
BRL_df.plot()
plt.tight_layout()
plt.title('Daily close value for BRL - USD')
plt.grid()
plt.show()

# %% [markdown]
# ## ARGENTINE PESO - ARS

# %%
#ARS-USD DATA
data, meta_data = fx.get_currency_exchange_daily(from_symbol='ARS',to_symbol='USD', outputsize='full')

ARS_df = pd.DataFrame()

for date in data:
    temp = pd.DataFrame(
    {
        "Date" : date,
        "ARS" : [data[date]['4. close']]
    }
    )
    
    ARS_df = pd.concat([ARS_df, temp], ignore_index=True)
ARS_df['Date'] = pd.to_datetime(ARS_df['Date'])
ARS_df['ARS'] = ARS_df['ARS'].astype('float')
ARS_df.set_index('Date', inplace = True)
ARS_df.sort_index(ascending=False)   
ARS_df.head()
# Out:
#                ARS
# Date
# 2021-02-03  0.0109
# 2021-02-02  0.0109
# 2021-02-01  0.0109
# 2021-01-29  0.0109
# 2021-01-28  0.0110

# %%
ARS_df.plot()
plt.tight_layout()
plt.title('Daily close value for ARS - USD')
plt.grid()
plt.show()

# %% [markdown]
# ## AUSTRALIAN DOLLAR - AUD

# %%
#AUD-USD DATA
data, meta_data = fx.get_currency_exchange_daily(from_symbol='AUD',to_symbol='USD', outputsize='full')

AUD_df = pd.DataFrame()

for date in data:
    temp = pd.DataFrame(
    {
        "Date" : date,
        "AUD" : [data[date]['4. close']]
    }
    )
    
    AUD_df = pd.concat([AUD_df, temp], ignore_index=True)
    
AUD_df['Date'] = pd.to_datetime(AUD_df['Date'])
AUD_df['AUD'] = AUD_df['AUD'].astype('float')
AUD_df.set_index('Date', inplace = True)
AUD_df.sort_index(ascending=False)  
AUD_df.head()
# Out:
#                AUD
# Date
# 2021-02-03  0.7608
# 2021-02-02  0.7604
# 2021-02-01  0.7635
# 2021-01-31  0.7620
# 2021-01-28  0.7670

# %%
AUD_df.plot()
plt.tight_layout()
plt.title('Daily close value for AUD - USD')
plt.grid()
plt.show()

# %% [markdown]
# ## BRITISH POUND - GBP

# %%
#GBP-USD DATA
data, meta_data = fx.get_currency_exchange_daily(from_symbol='GBP',to_symbol='USD', outputsize='full')

GBP_df = pd.DataFrame()

for date in data:
    temp = pd.DataFrame(
    {
        "Date" : date,
        "GBP" : [data[date]['4. close']]
    }
    )
    
    GBP_df = pd.concat([GBP_df, temp], ignore_index=True)
    
GBP_df['Date'] = pd.to_datetime(GBP_df['Date'])
GBP_df['GBP'] = GBP_df['GBP'].astype('float')
GBP_df.set_index('Date', inplace = True)
GBP_df.sort_index(ascending=False) 
GBP_df.head()
# Out:
#                GBP
# Date
# 2021-02-03  1.3664
# 2021-02-02  1.3665
# 2021-02-01  1.3658
# 2021-01-29  1.3699
# 2021-01-28  1.3720

# %%
GBP_df.plot()
plt.tight_layout()
plt.title('Daily close value for GBP - USD')
plt.grid()
plt.show()

# %% [markdown]
# ## JAPANESE YEN - JPY

# %%
#JPY-USD DATA
data, meta_data = fx.get_currency_exchange_daily(from_symbol='JPY',to_symbol='USD', outputsize='full')

JPY_df = pd.DataFrame()

for date in data:
    temp = pd.DataFrame(
    {
        "Date" : date,
        "JPY" : [data[date]['4. close']]
    }
    )
    
    JPY_df = pd.concat([JPY_df, temp], ignore_index=True)
    
JPY_df['Date'] = pd.to_datetime(JPY_df['Date'])
JPY_df['JPY'] = JPY_df['JPY'].astype('float')
JPY_df.set_index('Date', inplace = True)
JPY_df.sort_index(ascending=False)   
JPY_df.head()
# Out:
#                JPY
# Date
# 2021-02-03  0.0095
# 2021-02-02  0.0095
# 2021-02-01  0.0095
# 2021-01-29  0.0095
# 2021-01-28  0.0096

# %%
JPY_df.plot()
plt.tight_layout()
plt.title('Daily close value for JPY - USD')
plt.grid()
plt.show()

# %% [markdown]
# ## VENEZUELAN BOLIVAR - VES - the official currency since 20 August 2018

# %%
#VES - USD DATA
data, meta_data = fx.get_currency_exchange_daily(from_symbol='VES',to_symbol='USD', outputsize='full')

VES_df = pd.DataFrame()

for date in data:
    temp = pd.DataFrame(
    {
        "Date" : date,
        "VES" : [data[date]['4. close']]
    }
    )
    
    VES_df = pd.concat([VES_df, temp], ignore_index=True)
    
VES_df['Date'] = pd.to_datetime(VES_df['Date'])
VES_df['VES'] = VES_df['VES'].astype('float')
VES_df.set_index('Date', inplace = True)
VES_df.sort_index(ascending=False)   
VES_df.head()
# Out:
#             VES
# Date
# 2021-02-03  0.0
# 2021-02-02  0.0
# 2021-02-01  0.0
# 2021-01-31  0.0
# 2021-01-30  0.0

# %%
VES_df.plot()
plt.tight_layout()
plt.title('Daily close value for VES - USD')
plt.grid()
plt.show()

# %% [markdown]
# ## ALL CURRENCIES INTO ONE DATAFRAME & GRAPH

# %%
fx_df = pd.concat([EUR_df, ARS_df, BRL_df, AUD_df, GBP_df, JPY_df], axis = 1, join='inner')

# %%
fx_df.head()
# Out:
#                EUR     ARS     BRL     AUD     GBP     JPY
# Date
# 2021-02-03  1.2037  0.0109  0.1858  0.7608  1.3664  0.0095
# 2021-02-02  1.2042  0.0109  0.1858  0.7604  1.3665  0.0095
# 2021-02-01  1.2059  0.0109  0.1836  0.7635  1.3658  0.0095
# 2021-01-28  1.2120  0.0110  0.1833  0.7670  1.3720  0.0096
# 2021-01-27  1.2107  0.0110  0.1842  0.7651  1.3684  0.0096

# %%
fx_df = fx_df.loc['2021-01-29':'2017-01-01']
fx_df.tail(10)
# Out:
#                EUR     ARS     BRL     AUD     GBP     JPY
# Date
# 2017-01-17  1.0711  0.0624  0.3108  0.7551  1.2403  0.0089
# 2017-01-16  1.0599  0.0626  0.3079  0.7473  1.2020  0.0088
# 2017-01-12  1.0612  0.0628  0.3131  0.7488  1.2157  0.0087
# 2017-01-11  1.0583  0.0627  0.3123  0.7447  1.2204  0.0087
# 2017-01-10  1.0556  0.0627  0.3124  0.7362  1.2172  0.0086
# 2017-01-09  1.0584  0.0625  0.3122  0.7360  1.2172  0.0086
# 2017-01-05  1.0602  0.0622  0.3120  0.7338  1.2412  0.0087
# 2017-01-04  1.0487  0.0618  0.3104  0.7287  1.2320  0.0085
# 2017-01-03  1.0409  0.0622  0.3058  0.7230  1.2238  0.0085
# 2017-01-02  1.0462  0.0622  0.3038  0.7197  1.2275  0.0085

# %%
fx_df.plot(figsize=(10, 5))
plt.tight_layout()
plt.title('Daily close value - all currencies')
plt.grid()
plt.show()

# %% [markdown]
# ## PLOT

# %%
import pandas as pd
import hvplot.pandas
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fx_returns = fx_df.sort_index(ascending=True).pct_change().dropna()


fx_returns.info()
currency = ['EUR', 'ARS', 'AUD', 'GBP', 'JPY']

fx_returns.tail(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 832 entries, 2017-01-03 to 2021-01-28
# Data columns (total 6 columns):
# EUR    832 non-null float64
# ARS    832 non-null float64
# BRL    832 non-null float64
# AUD    832 non-null float64
# GBP    832 non-null float64
# JPY    832 non-null float64
# dtypes: float64(6)
# memory usage: 45.5 KB
#                  EUR       ARS       BRL       AUD       GBP       JPY
# Date
# 2021-01-13 -0.004015  0.000000  0.004269 -0.003729 -0.001684  0.000000
# 2021-01-14 -0.000411  0.000000  0.020191  0.003743  0.003593  0.000000
# 2021-01-18 -0.006337 -0.008929 -0.019271 -0.011445 -0.007380  0.000000
# 2021-01-19  0.004472  0.000000 -0.011683  0.003252  0.003092  0.000000
# 2021-01-20 -0.001979  0.000000  0.012896  0.005705  0.001835  0.010417
# 2021-01-21  0.004627  0.000000 -0.011141  0.000645  0.005713  0.000000
# 2021-01-25 -0.001727 -0.009009 -0.021459 -0.005412 -0.004006 -0.010309
# ...

# %%
fx_returns.hvplot()
# Out:
# :NdOverlay   [Variable]
#    :Curve   [Date]   (value)

# %% [markdown]
# ## COMPARISON FOREX DATA WITH BTC

# %%
#Read in Bitcoin Data 

btc_df = pd.read_csv("Data\BTC-USD.csv", index_col="Date", parse_dates=True, infer_datetime_format=True)
btc_df = btc_df.drop(columns=["Open", "High", "Low", "Adj Close", "Volume"]) #Keep relevant columns 
btc_df = btc_df.rename(columns={'Close':'BTC'}) #rename close column to BTC

#Read in Ethereum Data 
eth_df = pd.read_csv("Data\ETH-USD.csv", index_col="Date", parse_dates=True, infer_datetime_format=True)
eth_df = eth_df.drop(columns=["Open", "High", "Low", "Adj Close", "Volume"]) #Keep relevant columns 
eth_df = eth_df.rename(columns={'Close':'ETH'}) #rename close column to ETH

#Read in Gold Futures Prices 
gold_df = pd.read_csv("Data\Gold Futures Prices.csv", index_col="Date", parse_dates=True, infer_datetime_format=True)
gold_df = gold_df.drop(columns=["Vol.", "Open", "High", "Low", "Change %"]) #Keep relevant columns 
gold_df = gold_df.rename(columns={'Price':'GOLD'}) #rename close column to GOLD

# %%
#Concatenate Data

combined_df = pd.concat([btc_df, eth_df, gold_df] ,axis="columns", join="inner")
combined_df.head()
# Out:
#                     BTC       ETH      GOLD
# Date
# 2017-01-02  1021.750000   8.37851  1,151.05
# 2017-01-03  1043.839966   9.72525  1,244.70
# 2017-01-04  1154.729980  11.25160  1,247.10
# 2017-01-05  1013.380005  10.25440  1,262.10
# 2017-01-06   902.200989  10.25470  1,255.70

# %%
#Change Data type of "Gold" to float instead of object 

combined_df['GOLD'] = combined_df['GOLD'].str.replace(',', '')
combined_df['GOLD'] = combined_df['GOLD'].astype('float')

combined_returns = combined_df.pct_change().dropna()

# %%
all_df = pd.concat([fx_df, combined_df], axis= 1, join='inner' )

all_df.tail(10)
# Out:
#                EUR     ARS     BRL     AUD     GBP     JPY          BTC  \
# Date
# 2017-01-17  1.0711  0.0624  0.3108  0.7551  1.2403  0.0089   907.937988
# 2017-01-16  1.0599  0.0626  0.3079  0.7473  1.2020  0.0088   831.533997
# 2017-01-12  1.0612  0.0628  0.3131  0.7488  1.2157  0.0087   804.833984
# 2017-01-11  1.0583  0.0627  0.3123  0.7447  1.2204  0.0087   777.757019
# 2017-01-10  1.0556  0.0627  0.3124  0.7362  1.2172  0.0086   907.679016
# 2017-01-09  1.0584  0.0625  0.3122  0.7360  1.2172  0.0086   902.828003
# 2017-01-05  1.0602  0.0622  0.3120  0.7338  1.2412  0.0087  1013.380005
# 2017-01-04  1.0487  0.0618  0.3104  0.7287  1.2320  0.0085  1154.729980
# 2017-01-03  1.0409  0.0622  0.3058  0.7230  1.2238  0.0085  1043.839966
# 2017-01-02  1.0462  0.0622  0.3038  0.7197  1.2275  0.0085  1021.750000
#
#                  ETH     GOLD
# Date
# 2017-01-17  10.30230  1297.40
# 2017-01-16   9.63650  1202.85
# 2017-01-12   9.86133  1283.30
# 2017-01-11   9.71776  1280.00
# ...

# %%
ves_btc_df = pd.concat([VES_df, combined_df], axis=1 , join = 'inner')
ves_btc_df = ves_btc_df.loc['2021-01-01':'2019-01-01']
ves_btc_df.head()
# Out:
#             VES           BTC         ETH    GOLD
# Date
# 2021-01-01  0.0  29374.152344  730.367554  1901.6
# 2020-12-31  0.0  29001.720703  737.803406  1895.1
# 2020-12-30  0.0  28840.953125  751.618958  1893.4
# 2020-12-29  0.0  27362.437500  731.520142  1882.9
# 2020-12-28  0.0  27084.808594  730.397339  1880.4

# %%
# ARS vs. BTC

x = all_df.index
y1 = all_df['ARS']
y2 = all_df['BTC']

fig, ax1 = plt.subplots(figsize=(20,5))

ax2 = ax1.twinx()
ax1.plot(x, y1, 'g-', linewidth=2)
ax2.plot(x, y2, 'b-', linewidth=2)

ax1.set_xlabel('Date')
ax1.set_ylabel('ARS', color='g')
ax2.set_ylabel('BTC', color='b')


plt.show()

# %%
# EUR vs. BTC

x = all_df.index
y1 = all_df['EUR']
y2 = all_df['BTC']

fig, ax1 = plt.subplots(figsize=(20,5))

ax2 = ax1.twinx()
ax1.plot(x, y1, 'r-', linewidth=2)
ax2.plot(x, y2, 'b-', linewidth=2)

ax1.set_xlabel('Date')
ax1.set_ylabel('EUR', color='r')
ax2.set_ylabel('BTC', color='b')


plt.show()

# %%
# GBP vs. BTC

x = all_df.index
y1 = all_df['GBP']
y2 = all_df['BTC']

fig, ax1 = plt.subplots(figsize=(20,5))

ax2 = ax1.twinx()
ax1.plot(x, y1, 'k-', linewidth=2)
ax2.plot(x, y2, 'b-', linewidth=2)

ax1.set_xlabel('Date')
ax1.set_ylabel('GBP', color='k')
ax2.set_ylabel('BTC', color='b')


plt.show()

# %%
# JPY vs. BTC

x = all_df.index
y1 = all_df['JPY']
y2 = all_df['BTC']

fig, ax1 = plt.subplots(figsize=(20,5))

ax2 = ax1.twinx()
ax1.plot(x, y1, 'y-', linewidth=2)
ax2.plot(x, y2, 'b-', linewidth=2)

ax1.set_xlabel('Date')
ax1.set_ylabel('JPY', color='y')
ax2.set_ylabel('BTC', color='b')


plt.show()

# %%
# AUD vs. BTC

x = all_df.index
y1 = all_df['AUD']
y2 = all_df['BTC']

fig, ax1 = plt.subplots(figsize=(20,5))

ax2 = ax1.twinx()
ax1.plot(x, y1, 'm-', linewidth=2)
ax2.plot(x, y2, 'b-', linewidth=2)

ax1.set_xlabel('Date')
ax1.set_ylabel('AUD', color='m')
ax2.set_ylabel('BTC', color='b')


plt.show()

# %%
# BRL vs. BTC

x = all_df.index
y1 = all_df['BRL']
y2 = all_df['BTC']

fig, ax1 = plt.subplots(figsize=(20,5))

ax2 = ax1.twinx()
ax1.plot(x, y1, 'g-', linewidth=2)
ax2.plot(x, y2, 'b-', linewidth=2)

ax1.set_xlabel('Date')
ax1.set_ylabel('BRL', color='g')
ax2.set_ylabel('BTC', color='b')


plt.show()

# %%
# VES vs. BTC

x = ves_btc_df.index
y1 = ves_btc_df['VES']
y2 = ves_btc_df['BTC']

fig, ax1 = plt.subplots(figsize=(20,5))

ax2 = ax1.twinx()
ax1.plot(x, y1, 'g-', linewidth=2)
ax2.plot(x, y2, 'b-', linewidth=2)

ax1.set_xlabel('Date')
ax1.set_ylabel('VES', color='g')
ax2.set_ylabel('BTC', color='b')


plt.show()

# %% [markdown]
# ## Crypto Adoption in 2020 by Countries

# %%
## Crypto Adoption Index in 2020
## The data is a pdf index list which is published by Chainalysis

country_list = ['Venezula', 'Brazil', 'United Kingdom', 'Australia', 'Argentina', 'Japan' ]
fx_list = ['VES', ]
rank_list = [3, 13, 14, 20, 28, 71]

crypto_adoption_df = pd.DataFrame(
    {
        'Country' : country_list,
        'Rank' : rank_list
    }
)


crypto_adoption_df.hvplot.table()
# Out:
# :Table   [Country,Rank]

# %% [markdown]
# ## Conclusion

# %% [markdown]
#  #
# Especially, countries with the political and/or economic difficulties/uncertainty led people to invest in Crypto currencies like Bitcoin. The reason is to find alternative financial solutions due to devalue currency, increase in tax/interest rate, limit in amount to invest other currencies, etc.
#
# Venezuela (major effect: Hyperinflation), Argentina (high inflation) and Brazil are some example of the countries which has high growth in investing crypto currencies. These countries listed in top 30 in crypto adoption index.
#
# Crypto mostly is inversely correlation with economic growth. As we seen in Venezuela, Argentina and Brazil, these countries has devalued currency against USD and that is the reason why people want to invest in Crypto currencies.
